# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 451 kB 14.0 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 49.3 MB/s
# ...
#      |████████████████████████████████| 212 kB 13.7 MB/s
# ...
#      |████████████████████████████████| 182 kB 14.3 MB/s
# ...
#      |████████████████████████████████| 132 kB 36.2 MB/s
# ...
#      |████████████████████████████████| 127 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 36.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ECE1786_Project/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ECE1786_Project

# %%
import torch
from pathlib import Path
model_path = Path('/content/drive/MyDrive/ECE1786_Project/code_t5_finetuned_sorting.pt')
model= torch.load(model_path)

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codet5-base")
# Out:
# Downloading:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/703k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/294k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/12.5k [00:00<?, ?B/s]

# %%
import pandas as pd
Test = pd.read_csv('Test.csv')

# %% [markdown]
# ## Yuchen

# %%
Test[:28].shape
# Out:
# (28, 2)

# %%
Test[71:].shape
# Out:
# (15, 2)

# %% [markdown]
# ## Dhairya

# %%
Test[28:71].shape
# Out:
# (42, 2)

# %% [markdown]
# # Hand-Labelling the Results (Qualitative Results)

# %% [markdown]
# Describe the two metrics here

# %% [markdown]
# ## Sample 1

# %%
sample_input = Test["text"][0]
print('#sample_input:', sample_input, '\n')
input_ids = tokenizer(sample_input, return_tensors='pt').input_ids
outputs = model.generate(input_ids, max_new_tokens=500)
print('#generated output:')
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# #sample_input: 2 Write python code to sort an array in descending order using bubble sort
#
# #generated output:
# def bubbleSort(array):
#     swapped = False
#     for i in range(len(array)-1,0,-1):
#         for j in range(i):
#             if array[j]>array[j+1]:
#                 array[j], array[j+1] = array[j+1], array[j]
#                 swapped= True
#         if swapped:
#             swapped=False
#         else:
#             break
#     return array
# arr = [9,4,3,5,6,1,2,7]
# print(bubbleSort(arr))

# %%
#sample_input: 2 Write python code to sort an array in descending order using bubble sort 

#generated output:
def bubbleSort(array):
    swapped = False
    for i in range(len(array)-1,0,-1):
        for j in range(i):
            if array[j]>array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]
                swapped= True
        if swapped:
            swapped=False
        else:
            break
    return array
arr = [9,4,3,5,6,1,2,7]
print(bubbleSort(arr))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 9]

# %% [markdown]
# (a) Comment on the criteria for metric 1 corresponding to the generated output
#
# (b) Label for metric 1
#
# (c) Comment on the criteria for metric 2 corresponding to the generated output
#
# (d) Label for metric 2
